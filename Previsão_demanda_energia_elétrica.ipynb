# %% [markdown]
# <a href="https://colab.research.google.com/github/MarceloRRodrigues/Deep-Learning_Trabalho-final/blob/main/Previs%C3%A3o_demanda_energia_el%C3%A9trica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#teste

# %%
# Out:
# Seu nome: MarceloRRodrigues
# Seu email: marcelo.rrodrigues21@gmail.com
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# Nada para commitar
# Already up to date.
# Everything up-to-date
